# %% [markdown]
# # Causal Heterogeneity Backlog
#
# This notebook is reserved for a future heterogeneous-treatment-effect extension, likely kitchen uplift by neighborhood or home size. Phase 3 shipped the linear DML layer; causal forests were intentionally deferred in ADR-020 because EconML is optional and not required for the approved Phase 3 gate.
