# %% [markdown]
# # Phase 3 Notebook Pointer
#
# The approved Phase 3 causal analysis now lives in `03_causal.ipynb`. That notebook consumes the artifacts produced by `python -m margin_of_error.causal.dml` and contains the full DML framing, comparison table, decision matrix, and underwriting consequence review.
#
# This placeholder remains only to avoid breaking older scaffold links.
