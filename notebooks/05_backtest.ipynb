# %% [markdown]
# # ## Phase 4: The 2006–2010 Crash Backtest
#
# Walk-forward temporal backtest of the underwriting rule through the housing crash. Uses full De Cock Ames dataset sorted by sale date. Shows how the rule and model calibration behave under distribution shift.
#
# ---
#
# **Rule:** All reusable logic lives in . This notebook imports from there — no copy-paste logic here.
#
# **Requires Phase 4 approval.** Uses data/raw/ames/AmesHousing.csv only.

# %%
import sys
sys.path.insert(0, "../src")  # ensure src/ is on path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from margin_of_error.config import load_economics, load_model_config

economics = load_economics("../config/economics.yaml")
config = load_model_config("../config/model.yaml")

# Set global seed from config
np.random.seed(config.global_seed)
